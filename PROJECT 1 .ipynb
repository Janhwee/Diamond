# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
df=pd.read_csv("diamonds.csv")

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.scatter(df["carat"],df["price"])
plt.show()

# %%
sns.heatmap(df.select_dtypes(float).corr())
# Out:
# <Axes: >

# %%
df["x"].describe
# Out:
# <bound method NDFrame.describe of 0        3.95
# 1        3.89
# 2        4.05
# 3        4.20
# 4        4.34
#          ...
# 53935    5.75
# 53936    5.69
# 53937    5.66
# 53938    6.15
# 53939    5.83
# Name: x, Length: 53794, dtype: float64>

# %%
df[df["x"]==0]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
df.drop(df[df["x"]==0].index)
df.drop(df[df["y"]==0].index)
df.drop(df[df["z"]==0].index)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53775 rows x 10 columns]

# %%
sns.pairplot(df)
plt.show()

# %%
plt.bar(df["price"],df["clarity"])
plt.show()
plt.figure(figsize=(15,8))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  object
#  2   color    53794 non-null  object
#  3   clarity  53794 non-null  object
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  int64
#  7   x        53794 non-null  float64
#  8   y        53794 non-null  float64
#  9   z        53794 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 6.5+ MB

# %%
df.groupby("clarity")["price"].sum()
# Out:
# clarity
# I1       2904704
# IF       5121096
# SI1     52078024
# SI2     46275717
# VS1     31332182
# VS2     48032351
# VVS1     9214521
# VVS2    16616708
# Name: price, dtype: int64

# %%
plt.bar(df["clarity"],df["price"])
plt.bar_label(plt.bar(df["clarity"].unique(),df.groupby("clarity")["price"].mean(),color="violet"))
plt.show()

# %%
x=df.groupby("clarity")["price"].mean()
x
# Out:
# clarity
# I1      3925.275676
# IF      2870.569507
# SI1     3996.165132
# SI2     5057.455410
# VS1     3841.611329
# VS2     3927.741516
# VVS1    2526.602961
# VVS2    3286.532437
# Name: price, dtype: float64

# %%
plt.figure(figsize=(16,7))
plt.bar(x.index,x)
plt.bar_label(plt.bar(x.index,x.values,color="c"))
plt.show()

# %%
x=df.groupby("price")["y"].sum()
x
# Out:
# price
# 326      7.82
# 327      4.07
# 334      4.23
# 335      4.35
# 336      7.94
#          ...
# 18803    8.00
# 18804    8.13
# 18806    7.41
# 18818    7.97
# 18823    8.47
# Name: y, Length: 11602, dtype: float64

# %% [markdown]
# # HANDLING OUTLIERS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  object
#  2   color    53794 non-null  object
#  3   clarity  53794 non-null  object
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  int64
#  7   x        53794 non-null  float64
#  8   y        53794 non-null  float64
#  9   z        53794 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 6.5+ MB

# %%
plt.boxplot(df["carat"])
plt.show()

# %%
def IQR(x):
    q1=x.quantile(.25)
    q3=x.quantile(.75)
    IQR=q3-q1
    lf=q1-(1.5*IQR)
    uf=q3+(1.5*IQR)
    print("lf-->",lf,"uf-->",uf)

# %%
IQR(df["carat"])
# Out:
# lf--> -0.5599999999999999 uf--> 2.0

# %%
df["carat"]=np.where(df["carat"]>2.0,2.0,df["carat"])

# %%
plt.boxplot(df["carat"])
plt.show()

# %%
plt.boxplot(df["depth"])
plt.show()

# %%
IQR(df["depth"])
# Out:
# lf--> 58.75 uf--> 64.75

# %%
df["depth"]=np.where(df["depth"]>64.75,64.75,df["depth"])

# %%
plt.boxplot(df["depth"])
plt.show()

# %%
df["depth"]=np.where(df["depth"]<58.75,58.75,df["depth"])

# %%
plt.boxplot(df["depth"])
plt.show()

# %%
plt.boxplot(df["price"])
plt.show()

# %%
IQR(df["price"])
# Out:
# lf--> -5612.625 uf--> 11890.375

# %%
df["price"]=np.where(df["price"]>11890.375,11890.375,df["price"])

# %%
plt.boxplot(df["price"])
plt.show()

# %%
plt.boxplot(df["table"])
plt.show()

# %%
IQR(df["table"])
# Out:
# lf--> 51.5 uf--> 63.5

# %%
df["table"]=np.where(df["table"]>63.5,63.5,df["table"])

# %%
plt.boxplot(df["table"])
plt.show()

# %%
df["table"]=np.where(df["table"]<51.5,51.5,df["table"])

# %%
plt.boxplot(df["table"])
plt.show()

# %%
plt.boxplot(df["x"])
plt.show()

# %%
IQR(df["x"])
# Out:
# lf--> 1.9649999999999999 uf--> 9.285

# %%
df["x"]=np.where(df["x"]>9.285,9.285,df["x"])

# %%
plt.boxplot(df["x"])
plt.show()

# %%
df["x"]=np.where(df["x"]<2,2,df["x"])

# %%
plt.boxplot(df["x"])
plt.show()

# %%
plt.boxplot(df["y"])
plt.show()

# %%
IQR(df["y"])
# Out:
# lf--> 1.9899999999999993 uf--> 9.27

# %%
df["y"]=np.where(df["y"]>9.27,9.27,df["y"])

# %%
plt.boxplot(df["y"])
plt.show()

# %%
df["y"]=np.where(df["y"]<2,2,df["y"])

# %%
plt.boxplot(df["y"])
plt.show()

# %%
plt.boxplot(df["z"])
plt.show()

# %%
IQR(df["z"])
# Out:
# lf--> 1.23 uf--> 5.710000000000001

# %%
df["z"]=np.where(df["z"]>5.71,5.71,df["z"])

# %%
plt.boxplot(df["z"])
plt.show()

# %%
df["z"]=np.where(df["z"]<1.23,1.23,df["z"])

# %%
plt.boxplot(df["z"])
plt.show()

# %%
df.ffill(inplace=True)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df
# Out:
#        carat        cut color clarity  depth  table   price     x     y     z
# 0       0.23      Ideal     E     SI2  61.50   55.0   326.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1  59.80   61.0   326.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1  58.75   63.5   327.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2  62.40   58.0   334.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2  63.30   58.0   335.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1  60.80   57.0  2757.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1  63.10   55.0  2757.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1  62.80   60.0  2757.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2  61.00   58.0  2757.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2  62.20   55.0  2757.0  5.83  5.87  3.64
#
# [53794 rows x 10 columns]

# %% [markdown]
# DUMMIES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53794 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53794 non-null  float64
#  1   cut      53794 non-null  object
#  2   color    53794 non-null  object
#  3   clarity  53794 non-null  object
#  4   depth    53794 non-null  float64
#  5   table    53794 non-null  float64
#  6   price    53794 non-null  float64
#  7   x        53794 non-null  float64
#  8   y        53794 non-null  float64
#  9   z        53794 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 6.5+ MB

# %%
#making dummies
df1=pd.get_dummies(df,columns=["cut","color","clarity"])

# %%
df1
# Out:
#        carat  depth  table   price     x     y     z  cut_Fair  cut_Good  \
# 0       0.23  61.50   55.0   326.0  3.95  3.98  2.43     False     False
# 1       0.21  59.80   61.0   326.0  3.89  3.84  2.31     False     False
# 2       0.23  58.75   63.5   327.0  4.05  4.07  2.31     False      True
# 3       0.29  62.40   58.0   334.0  4.20  4.23  2.63     False     False
# 4       0.31  63.30   58.0   335.0  4.34  4.35  2.75     False      True
# ...      ...    ...    ...     ...   ...   ...   ...       ...       ...
# 53935   0.72  60.80   57.0  2757.0  5.75  5.76  3.50     False     False
# 53936   0.72  63.10   55.0  2757.0  5.69  5.75  3.61     False      True
# 53937   0.70  62.80   60.0  2757.0  5.66  5.68  3.56     False     False
# 53938   0.86  61.00   58.0  2757.0  6.15  6.12  3.74     False     False
# 53939   0.75  62.20   55.0  2757.0  5.83  5.87  3.64     False     False
#
#        cut_Ideal  ...  color_I  color_J  clarity_I1  clarity_IF  clarity_SI1  \
# ...

# %%
df1.columns
# Out:
# Index(['carat', 'depth', 'table', 'price', 'x', 'y', 'z', 'cut_Fair',
#        'cut_Good', 'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'color_D',
#        'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J',
#        'clarity_I1', 'clarity_IF', 'clarity_SI1', 'clarity_SI2', 'clarity_VS1',
#        'clarity_VS2', 'clarity_VVS1', 'clarity_VVS2'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.model_selection import train_test_split

# %%
y = df1["price"] # target variable/ dependent variables 
x = df1[['carat', 'depth', 'table', 'x', 'y',
       'z']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=80)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (37655, 6)
# (37655,)
# (16139, 6)
# (16139,)

# %%
x_train.columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
y
# Out:
# 0         326.0
# 1         326.0
# 2         327.0
# 3         334.0
# 4         335.0
#           ...
# 53935    2757.0
# 53936    2757.0
# 53937    2757.0
# 53938    2757.0
# 53939    2757.0
# Name: price, Length: 53794, dtype: float64

# %%
y_train
# Out:
# 52464    2516.0
# 16350     608.0
# 28978     436.0
# 41910    1261.0
# 17977    7272.0
#           ...
# 8734     4460.0
# 35127     888.0
# 19407    8064.0
# 38189    1015.0
# 17623    7096.0
# Name: price, Length: 37655, dtype: float64

# %%
import statsmodels.api as sm

# %%
x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test)

# %%
x_train
# Out:
#        const  carat  depth  table     x     y     z
# 52464    1.0   0.70   61.1   57.0  5.75  5.71  3.50
# 16350    1.0   0.30   62.9   59.0  4.30  4.26  2.69
# 28978    1.0   0.25   63.3   56.0  4.01  4.05  2.55
# 41910    1.0   0.47   61.7   56.0  5.01  4.98  3.08
# 17977    1.0   1.51   62.7   55.0  7.27  7.18  4.53
# ...      ...    ...    ...    ...   ...   ...   ...
# 8734     1.0   0.90   62.3   60.0  6.08  6.00  3.76
# 35127    1.0   0.37   61.0   59.0  4.65  4.60  2.82
# 19407    1.0   1.25   61.9   58.0  6.91  6.85  4.26
# 38189    1.0   0.41   62.1   59.0  4.76  4.74  2.95
# 17623    1.0   1.20   64.0   61.0  6.67  6.61  4.25
#
# [37655 rows x 7 columns]

# %%
model1=sm.OLS(y_train,x_train).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                 4.795e+04
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):               0.00
# Time:                        23:23:36   Log-Likelihood:            -3.1940e+05
# No. Observations:               37655   AIC:                         6.388e+05
# Df Residuals:                   37648   BIC:                         6.389e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.419e+04    571.854     24.807      0.000    1.31e+04    1.53e+04
# ...

# %%
sns.distplot(df["price"])
plt.show()

# %%
df1["price_log"]=np.log(df1["price"])

# %%
y = df1["price_log"] # target variable/ dependent variables 
x = df1[['carat', 'depth', 'table', 'x', 'y',
       'z' ]] # independent variable
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=80)

# %%
x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test)
model2=sm.OLS(y_train,x_train).fit()

# %%
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              price_log   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                 7.836e+04
# Date:                Sun, 14 Jul 2024   Prob (F-statistic):               0.00
# Time:                        23:23:37   Log-Likelihood:                -4032.1
# No. Observations:               37655   AIC:                             8078.
# Df Residuals:                   37648   BIC:                             8138.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4478      0.132     -3.396      0.001      -0.706      -0.189
# ...

# %%
actual=np.exp(y_train)
pre=np.exp(model2.predict(x_train))
error=actual-pre

# %%
print("MSE",np.mean(np.square(error)))
print("RMSE",np.sqrt(np.mean(np.square(error))))
print("MAE",np.mean(np.abs(error)))
# Out:
# MSE 4706270.003968281
# RMSE 2169.393925493542
# MAE 858.3185524878443

# %%
y = df1["price_log"] # target variable/ dependent variables 
x = df1[['carat', 'depth', 'table', 'x', 'y',
       'z' ]] # independent variable
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=80)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9258642157950974

# %%
x_train
# Out:
#        carat  depth  table     x     y     z
# 52464   0.70   61.1   57.0  5.75  5.71  3.50
# 16350   0.30   62.9   59.0  4.30  4.26  2.69
# 28978   0.25   63.3   56.0  4.01  4.05  2.55
# 41910   0.47   61.7   56.0  5.01  4.98  3.08
# 17977   1.51   62.7   55.0  7.27  7.18  4.53
# ...      ...    ...    ...   ...   ...   ...
# 8734    0.90   62.3   60.0  6.08  6.00  3.76
# 35127   0.37   61.0   59.0  4.65  4.60  2.82
# 19407   1.25   61.9   58.0  6.91  6.85  4.26
# 38189   0.41   62.1   59.0  4.76  4.74  2.95
# 17623   1.20   64.0   61.0  6.67  6.61  4.25
#
# [37655 rows x 6 columns]

# %%
lr.intercept_
# Out:
# -0.4477570638280852

# %%
lr.coef_
# Out:
# array([-1.21249466,  0.02868243, -0.00489391,  0.59448741,  0.60772039,
#         0.22599815])

# %%
lr.predict(x)
# Out:
# array([6.08430119, 5.8825576 , 6.05085005, ..., 7.83232234, 8.19585812,
#        8.0135673 ])

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
actual=np.exp(y_train)
pre=np.exp(lr.predict(x_train))

# %%
MAP=mean_absolute_percentage_error(actual,pre)
MSE=mean_squared_error(actual,pre)
MAE=mean_absolute_error(actual,pre)

# %%
print("MAP",MAP)
print("MSE",MSE)
print("MAE",MAE)
# Out:
# MAP 0.21041960300014773
# MSE 4706270.003967424
# MAE 858.3185524878157

# %%
#lr.predict
